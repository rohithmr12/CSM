# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
x=np.linspace(-10,10,10000)
y=x**2+ 2*x +2
fig,ax=plt.subplots()
a=ax.plot(x,y)

# %%
fig,ax=plt.subplots()
ax.set_xlim([-2,0])
ax.set_ylim([0.5,1.5])
a=ax.plot(x,y)

# %%
from sympy import *
x=symbols('x')
f=x**10 +x-10
fdash=diff(f,x)

# %%
fdash
# Out:
# 10*x**9 + 1

# %%
fdash.subs(x,4)
# Out:
# 2621441

# %%
import matplotlib.pyplot as plt
import numpy as np

x = symbols('x')
f = x**10 + x - 10
fdash = diff(f, x)

f_func = lambdify(x, f, 'numpy')
fdash_func = lambdify(x, fdash, 'numpy')

x_values = np.linspace(-2, 2, 400)

y_values_f = f_func(x_values)
y_values_fdash = fdash_func(x_values)

plt.figure(figsize=(8, 6))
plt.plot(x_values, y_values_f)
plt.plot(x_values, y_values_fdash)

plt.show()

# %%
pip install torch
# Out:
# Requirement already satisfied: torch in d:\users\admin\anaconda3\lib\site-packages (2.1.1)
# Requirement already satisfied: filelock in d:\users\admin\anaconda3\lib\site-packages (from torch) (3.9.0)
# Requirement already satisfied: typing-extensions in d:\users\admin\anaconda3\lib\site-packages (from torch) (4.6.3)
# Requirement already satisfied: sympy in d:\users\admin\anaconda3\lib\site-packages (from torch) (1.11.1)
# Requirement already satisfied: networkx in d:\users\admin\anaconda3\lib\site-packages (from torch) (2.8.4)
# Requirement already satisfied: jinja2 in d:\users\admin\anaconda3\lib\site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in d:\users\admin\anaconda3\lib\site-packages (from torch) (2023.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\users\admin\anaconda3\lib\site-packages (from jinja2->torch) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in d:\users\admin\anaconda3\lib\site-packages (from sympy->torch) (1.2.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch

# %%
x=torch.tensor(5.0)

# %%
x
# Out:
# tensor(5.)

# %%
x = torch.tensor([1.0], requires_grad=True)

# %%
y=x**2

# %%
plt.plot(x,y)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 plt.plot(x,y)
#
# File d:\Users\Admin\anaconda3\Lib\site-packages\matplotlib\pyplot.py:2812, in plot(scalex, scaley, data, *args, **kwargs)
#    2810 @_copy_docstring_and_deprecators(Axes.plot)
#    2811 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2812     return gca().plot(
#    2813         *args, scalex=scalex, scaley=scaley,
#    2814         **({"data": data} if data is not None else {}), **kwargs)
#
# File d:\Users\Admin\anaconda3\Lib\site-packages\matplotlib\axes\_axes.py:1690, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1688 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1689 for line in lines:
# -> 1690     self.add_line(line)
#    1691 if scalex:
#    1692     self._request_autoscale_view("x")
#
# File d:\Users\Admin\anaconda3\Lib\site-packages\matplotlib\axes\_base.py:2304, in _AxesBase.add_line(self, line)
#    2301 if line.get_clip_path() is None:
#    2302     line.set_clip_path(self.patch)
# -> 2304 self._update_line_limits(line)
#    2305 if not line.get_label():
#    2306     line.set_label(f'_child{len(self._children)}')
#
# File d:\Users\Admin\anaconda3\Lib\site-packages\matplotlib\axes\_base.py:2327, in _AxesBase._update_line_limits(self, line)
#    2323 def _update_line_limits(self, line):
#    2324     """
#    2325     Figures out the data limit of the given line, updating self.dataLim.
#    2326     """
# -> 2327     path = line.get_path()
#    2328     if path.vertices.size == 0:
#    2329         return
#
# File d:\Users\Admin\anaconda3\Lib\site-packages\matplotlib\lines.py:1029, in Line2D.get_path(self)
#    1027 """Return the `~matplotlib.path.Path` associated with this line."""
#    1028 if self._invalidy or self._invalidx:
# -> 1029     self.recache()
#    1030 return self._path
#
# File d:\Users\Admin\anaconda3\Lib\site-packages\matplotlib\lines.py:657, in Line2D.recache(self, always)
#     655 if always or self._invalidx:
#     656     xconv = self.convert_xunits(self._xorig)
# --> 657     x = _to_unmasked_float_array(xconv).ravel()
#     658 else:
#     659     x = self._x
#
# File d:\Users\Admin\anaconda3\Lib\site-packages\matplotlib\cbook\__init__.py:1335, in _to_unmasked_float_array(x)
#    1333     return np.ma.asarray(x, float).filled(np.nan)
#    1334 else:
# -> 1335     return np.asarray(x, float)
#
# File d:\Users\Admin\anaconda3\Lib\site-packages\torch\_tensor.py:1032, in Tensor.__array__(self, dtype)
#    1030     return self.numpy()
#    1031 else:
# -> 1032     return self.numpy().astype(dtype, copy=False)
#
# RuntimeError: Can't call numpy() on Tensor that requires grad. Use tensor.detach().numpy() instead.

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

group1 = np.random.rand(25)
group2 = np.random.rand(20)

variance1 = np.var(group1)
variance2 = np.var(group2)

f_value = variance1 / variance2

df1 = len(group1) - 1
df2 = len(group2) - 1

p_value = stats.f.cdf(f_value, df1, df2)

print('Degree of freedom 1:',df1)
print('Degree of freedom 2:',df2)
print("F-statistic:", f_value)
print("p-value:", p_value)
# Out:
# Degree of freedom 1: 24
# Degree of freedom 2: 19
# F-statistic: 1.6691561527690624
# p-value: 0.8711286268225438

# %%
df1 = 7
df2 = 13


sample1 = np.random.chisquare(df1,size=1000)
sample2 = np.random.chisquare(df2,size=1000)

f_value = (sample1/df1)/(sample2/df2)

f_value = np.sort(f_value)
pdf = stats.f.pdf(f_value,df1,df2)
cdf = stats.f.cdf(f_value,df1,df2)

p_value = 1 - cdf

plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.plot(f_value,pdf)
plt.title("F-Distribution PDF")
plt.xlabel('x')
plt.grid(True)
plt.ylabel("Probability_density")
plt.subplot(1,2,2)
plt.plot(f_value,cdf)
plt.title("F-dist CDF")
plt.xlabel('x')
plt.ylabel("Cumulative Density")
plt.grid(True)
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
